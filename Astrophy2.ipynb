# %% [markdown]
# <h1 style="text-align:center; font-family: 'Brush Script MT', cursive; font-size: 50px; color: rgba(19, 3, 83, 1);">
#     Sahasra’s Deep Dives into the Cosmos
# </h1>
#
# <p style="text-align:center; font-size: 20px; font-style: italic;">
#     My personal journey exploring the wonders of Quantum Mechanics, Relativity, and Astrophysics — one wavefunction at a time.
# </p>
#
# ---
#
# # 🌌 Intro: Wave-Particle Duality
#
# > “An electron is not just a particle. It sings — as a wave.”
#
# - Why do electrons only exist in certain energy levels?
# - What does it mean for an electron to be a standing wave?
# - What happens when we excite it to a higher level?
#
# 🧠 *My Thoughts:*
#
#
#
#
#
# The schrodinger's wave function says us not about the exact presence or absence of an electron, but about the probability of it being present or absent:- also known as electron density.
# Now, why would an electron typically be absent at a certain place? Why arent the electrons randomly scattered across the nucleus?
# Why are they present at certain places where the electron density is high?
# These places are known as energy levels.
# Allot of us probably think electrons and photons only exhibit one type of nature:- particle. Since obviously, theyre particles arent they? But whats shocking is, they show dual nature- of both a particle and a wave... but how???
#
# An electron acts as a standing wave. But why and how?
#
# If it was just a tiny particle - then why everytime we try to measure where it is precisely, we end up losing track of how fast or where it's going?... this is known as the <i>Principle of Superposition</i>
#
# Also the double slit experiment, where we gun out an electron one at a time showed that, it forms ripples and <i>interferes</i> with itself rather than acting just like a particle. Which takes us to a conclusion that it creates interferance patterns which only waves exhibit. But here's the catch~ an electron isnt a moving wave- its a standing one...
#
# Now whats a moving wave and standing wave?
#
# If waves are not bound and are free to move- theyre called as moving waves. So yall prolly know that an electrons are bound around an atom (specifically talking about them, not free electrons), and theyre confined to a specific <b>Couloumb Potential </b>(the pull by the nucleus)  ... so they act as standing waves.
#
# ---
# So the reason the electron doesn’t just “sit” somewhere or move around like a planet is because:
# 🔹 It's a wave,
# 🔹 Confined to specific patterns (standing waves),
# 🔹 And its stability comes from constructive interference — only whole numbers of wavelengths “fit” around the atom.
#
# Now what if we try to excite an electron to a higher energy level?
# Wouldn't that go against the idea that an electron can only exist at specific wavelengths and energy levels?
# Well — kinda, yeah. That's why electrons don’t just jump to any energy level — they only go to levels where a stable standing wave (with a whole number of wavelengths) can exist.
#
# So when we excite an electron, we have to give it just the right amount of energy — matching the difference between two allowed energy levels. If that works, the electron temporarily jumps up to the higher level.
#
# But it doesn’t stay there forever — it’s unstable.
# So what does it do?
#
# 💥 It drops back down to its lower energy level and emits a photon with exactly the same energy as the gap between the two levels.
# This isn’t to “nullify” the energy— it’s just nature’s way of balancing the books.
#
# The standing wave pattern shifts to match the new energy level — which means the wavelength and shape of the wave changes, but still obeys the rule of constructive interference, and not destructive which ofcourse prevents the atom from self destructing
#
# Now, on what basis is an energy level labelled as "allowed" while exciting it?
#
# Basically, an electron can only exist where the wavefunction holds true, and theres a non zero value to it, meaning theres a 'x' amount of probability for it to exist, while maintaining the stability of the atom.
#
#
#
#
#
#
#
# # 🔭 Random Thought 2: Wormholes & Space-Time Shortcuts
#
# ✎ “Wormholes don’t make you go faster than light. They just let you cheat spacetime.”
#
# - My apple-ant analogy 🍎🐜
# - Exotic matter & time travel?
# - What does general relativity say?
#
# ---
#
# Okay so basically THIS TOPIC IS SO OUT OF THE CONTEXT lol, but no worries. This aint Feynman's dump or some nerd's thesis. Its just me wondering about stuff like this.
#
# Sooo, think of an ant on one end of an apple tryna reach to the exactly opposite end. There's two ways it can do that~ go through by the circumference or dig a 'tunnel' to the opposite end. I guess its obvious enough that the second way is the so called 'shortcut'.
#
# This is exactly where the concept of wormhole comes from, js like its name ... its a shortcut.
# But what kinda shortcut?
#
# Usually, if we want to reduce the time we want to reach a place , we either increase our velocity or just reduce the distance. Conventionally, it's obvious for people to assume that reducing the distance means changing the destination. But the concept of wormholes states otherwise. The destination remains the same, but since you take a 'shortcut' to reaching it, the distance logically is reduced by ALLOT.
#
# Like, as in the concept of spacetime, if a satallite is trying to reach it a nearby star, it usually could take it 'x' light years, but with the help of a hypothetical wormhole, it can reach there in 'x' milliseconds.
#
# But this is where the plot twist enters, a wormhole self destructs itself insantly if we ever tried creating it with 'normal matter' with a attractive gravitational force. Because it causes the tunnel to cave in and just destruct itself. Attractive gravitational feild is produced by positive energy density. But what if we use something with a repulsive gravitational force  which counters gravity and keeps te tunnel open? This is what is known as 'exotic matter'. Its something with negative energy density and negative pressure.
#
# But our current levels of knowledge do not allow us to generate such exotic matter..
#
# Wheeler, a scientist once suggested that at Planck's scale (10^-35 m) , the spacetime isnt smooth, which causes irregularities to form tiny wormholes which are known to self collapse too.
#
# But what's a planck's scale??
# It is the smallest unit at a quantum level till where the principles of physics, and relativity apply. Since allot of the theories dont apply beyond that scale, spacetime might not even be continous there- it might be quantised or irregular ( foamy )...
# The physics doesnt cease to exist , but needs a new language beyond the planck's scale ( at even more micro level )...
#
# Sooo for now wormholes are just hypothetical ... ( ik thats sad)
#
#
# # ❓ My Quantum Questions
#
# - What if our universe exists *only* because of standing wave harmony?
# - Can wormholes act like time machines via acceleration?
#
#
#
# ---
