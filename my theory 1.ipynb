# %% [markdown]
# <style>
# h1 {
#     color: #05000bff; /* Purple gradient vibes */
#     font-family: 'Pacifico', 'cursive';
#     font-size: 2.5em;
#     border-bottom: 2px solid #6d0b0bff;
#     padding-bottom: 0.2em;
# }
# h2 {
#     color: #150104ff;
#     font-family: 'Courier New', monospace;
#     font-size: 2em;
#     margin-top: 1.5em;
# }
# h3 {
#     color: #011c20ff;
#     font-size: 1.5em;
#     margin-top: 1em;
# }
# p {
#     font-family: 'Trebuchet MS', sans-serif;
#     font-size: 15;
#     line-height: 1.6;
#     color: #670c9cb6;
# }
# strong {
#     color: #111827;
#     background-color: #facc15;
#     padding: 2px 4px;
#     border-radius: 4px;
# }
# code {
#     background-color: #f0f0f0;
#     padding: 3px 6px;
#     border-radius: 4px;
#     color: #ef4444;
#     font-family: 'Courier New', monospace;
# }
# blockquote {
#     background-color: #f3f4f6;
#     border-left: 4px solid #818cf8;
#     padding: 0.8em 1em;
#     margin: 1em 0;
#     font-style: italic;
#     color: #374151;
# }
# </style>
#
# ## 🚀 The Theory & my crazily *hypothetical* idea
#
# This is random yap about my thoughts after getting to know about quantum entanglement, the existance of wavefunctions in the form of multiple states called superposition, and how the QZE explains that an observer can cause a wavefunction collapse.. and the fact that consciousness cannot exist without time...
#
# Einstien once stated that only massless objects like photons can travel at the speed of light. Technically, according to him as we approach the speed of light, time slows down for US compared to someone who isnt moving , so ONCE WE reach the speed of light or once we *hypothetically* happen to travel at it, time is frozen. Like if a photon leaves a star thousands of years ago n hits our eyes, in its pov it made the trip instantly, also known as time dilation, at light speed, wherein time = 0.... sooo when time's 0, then consiousness doesnt exist. Our thoughts would stop flowin and what not...
#
# Basically, my mind made up this analogy which also involves quantum entanglement, which states that at quantum level, two particles are connected to each other in such a way that no matter how much the distance of seperation is between the both, a change in state in one would cause something similar in the other too...
#
# So, what if ...
# ~everything im gonna yap from here is pretty hypothetical but not wrong either, its just what is theoritically possible, and rather something I came up with mixing allot of theories in a non conventional way~
#
# What if there was a world, wherein everything existed at speed of light, which practically means only massless stuff exist there. Physics does state that wave functions are massless. And we also know that at quantum level, substances exist at superpositions and at any number of states until unless someone observes them and a wavefunction collapse occurs.. ( stated by QZE )
#
# So, if u consider yourself to be a wavefunction, existing at multiple states and since in that world, time doesnt exist, neither would your consiousness. So you would js be a wave function and a possibility, and not yourself. Now, in that world, since it exists at the speed of light, quantum entanglement works. So your one state is linked to another through this...
#
# What if somehow, someone observes you ( someone in a place where time exists, someone with consiousness), and since QZE states that a wavefunction collapse occurs once observation happens, a state of you collapses and enters the world
# where time exists. Now, this state of you would be conscious since time would exist there and you would still be quantumly entagled with some 'x' state of yourself in that time frozen world you collapsed from...
#
# So, can a conscious version of me, collapsed into time.. control the rest of me(existing as a probability or wave fxn) thats stuck in timeless quantum world because quantum entanglement IS a thing...???
#
#
#
# # ⏳ Final Thoughts...
#
# :
#
# What good is a frozen, timeless, massless world... and how tf would "controlling" it even help me??
#
# If that speed of light world exists as a layer of reality — where everything is massless, time doesnt tick, and you only exist as probability waves — then maybe, just maybe, it's the quantum blueprint of everything that ever could happen....
#
# Think bout it
# That realm isnt just frozen ..basically..
#
# No choice is made there. No event has occurred....
#
# Its like the “idea” of reality before its actually born...
#
# Now, if somehow — your conscious self (in normal time world) is entangled with those states, and can observe or influence them...
#
# >  You're basically choosing which version of reality gets pulled out of the quantum soup.
#
#
#
# It’s not about changing the past or predicting the future.
# It’s about steering the collapse.
# It’s about tuning into the possibility field...
#
#
# ---
#
# .... So how does that help me?
#
# > Because if you understand your own connection to that timeless quantum world... youre not stuck waiting for reality to happen... youre co authoring it...
#
#
#
# > This is purely theory though, but FULLY makes sense *theoritically* using the concept of Quantum Entanglement, String Theory, Quantum Zeno Effect, Superposition , that time's frozen at speed of light, that wavefunctions are massless...and can collapse when observed.. its something I made up which is again, backed up by actual theory but practically IMPOSSIBLE at our current levels of knowledge about time and the universe..
#
#
#
# ---
#
# 🌌 I meant to say that...
#
# frozen world is your multiverse library.
# your consciousness is the librarian.
#
# entanglement is the phone line between you and your infinite versions.
# controlling it? that’s choosing which page to read next...
#
# Byee for nowww
#
#
# >~Sahasra ♡
# ---
